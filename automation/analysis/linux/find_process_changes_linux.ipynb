# %% [markdown]
# # Purpose
#
# The purpose of this notebook is to compute the list of processes in a Linux scenario and the proportion of their occurrence in the trace.
#
# Note that this notebook is distributed for distribution purpose, and not intended for production use.
#
# # Perimeter
#
# - Linux 64-bit scenarios for which
#   [OSSI is supported by REVEN](http://doc.tetrane.com/professional/latest/Project-Manager/Workflow/Get-OSSI-Linux.html#vm-requirements).
# - Supported REVEN version: 2.8.2+
#
#
# # Limitations
#
# - The `current_task_offset` variable must be read from the `kernel_description.json` file of the target scenario.
#   This file can be found in the replay directory of the target scenario.
# - Possible changes of the value in `gs_base` and `kernel_gs_base` are ignored, with the assumption that the value
#   never changes and is simply swapped between `gs_base` and `kernel_gs_base`. If this assumption is incorrect, then
#   process changes will be missed.

# %% [markdown]
# ## Parameters

# %%
# Server connection
host = 'localhost'
port = 41607

# Required field offset from gs_base for current_task, find it in kernel_description.json
current_task_offset = 0xd300  # Correct value for the Fedora VM that is distributed by Tetrane

# %%
import reven2
server = reven2.RevenServer(host, port)
print(server.trace.transition_count)
# Out:
# 4257686967

# %%
# As in Linux 64bit, gs_base and kernel_gs_base don't seem to change but are just swap 
# we can use just the memory history to track the changes of process
def get_process_changes():
    tr = server.trace.transition(0)
    ctx_before = tr.context_before()
    current_process = ctx_before.ossi.process()
        
    yield tr

    gs_base = ctx_before.read(reven2.arch.msr.gs_base)

    if gs_base == 0:
        gs_base = ctx_before.read(reven2.arch.msr.kernel_gs_base)

    # FIXME: If MMU change the physical address of this linear address it won't work
    for memaccess in server.trace.memory_accesses(
        reven2.address.LinearAddress(gs_base + current_task_offset),
        8,
        from_transition=tr,
        operation=reven2.memhist.MemoryAccessOperation.Write
    ):
        memaccess_transition = memaccess.transition
        if current_process.pid != memaccess_transition.context_after().ossi.process().pid:
            yield memaccess_transition
        
            tr = memaccess_transition
            current_process = tr.context_after().ossi.process()

# %%
# %%time
# %%prun -s time

processes = {}
last_transition_id = 0

try:
    for tr in get_process_changes():
        current_process = tr.context_before().ossi.process()
        next_process = tr.context_after().ossi.process()
        
        current_process_tuple = (current_process.name, current_process.pid)

        if current_process_tuple not in processes:
            processes[current_process_tuple] = 0

        print("Changing to process %s at %s" % (next_process, tr))

        processes[current_process_tuple] += tr.id - last_transition_id
        last_transition_id = tr.id
        
    last_transition_id = server.trace.transition_count
except KeyboardInterrupt:
    print("Interrupted by user")
# Out:
# Changing to process exploit_userspe (1541) at #0 ret
# Changing to process xfce4-terminal (974) at #29672 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process ksoftirqd/0 (7) at #46860 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process kworker/0:1 (1432) at #55342 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process ksoftirqd/0 (7) at #65937 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process xfce4-terminal (974) at #68477 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1541) at #104729 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process xfce4-terminal (974) at #127753 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1541) at #243895 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process xfce4-terminal (974) at #300472 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1541) at #374985 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process xfce4-terminal (974) at #395510 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1541) at #420565 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process xfce4-terminal (974) at #1261304 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1541) at #1272723 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process xfce4-terminal (974) at #3407443 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1541) at #3439879 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process xfce4-terminal (974) at #4849038 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1541) at #4875401 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process xfce4-terminal (974) at #5687811 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1541) at #5734792 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process xfce4-terminal (974) at #6051873 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1541) at #6093587 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process xfce4-terminal (974) at #7352420 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1541) at #7402288 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process xfce4-terminal (974) at #8997254 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1541) at #9026798 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process xfce4-terminal (974) at #10746962 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1541) at #10798684 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process xfce4-terminal (974) at #12387189 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process Xorg (614) at #12416005 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process ksoftirqd/0 (7) at #12457135 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process xfce4-terminal (974) at #12464803 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1541) at
mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process accounts-daemon (549) at #4253441115 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process gmain (551) at #4253444260 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process accounts-daemon (549) at #4253447472 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process gmain (551) at #4253452372 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process accounts-daemon (549) at #4253455610 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sudo (1541) at #4253469446 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4253511477 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process gmain (999) at #4253514597 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process gmain (1021) at #4253520603 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process gmain (520) at #4253524099 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process accounts-daemon (549) at #4253527608 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4253537528 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sudo (1541) at #4253541072 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process gmain (1021) at #4253551359 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sudo (1541) at #4253554431 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process gmain (999) at #4253558419 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sudo (1541) at #4253561431 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_be (497) at #4253569025 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4253587067 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_be (497) at #4253590578 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4253600201 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process gmain (520) at #4253603751 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_be (497) at #4253606885 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4253620485 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sudo (1541) at #4253623514 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4253686746 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process accounts-daemon (549) at #4253689862 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4253699010 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_be (497) at #4253702584 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4253715296 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process gmain (551) at #4253719440 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4253745049 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_be (497) at #4253748729 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4253760068 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sudo (1541) at #4253763200 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4253868452 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process ksoftirqd/0 (7) at #4253870914 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process kworker/0:1H (257) at #4253879146 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process ksoftirqd/0 (7) at #4253881202 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process accounts-daemon (549) at #4253883414 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process gmain (551) at #4253901009 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4253912517 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_nss (545) at #4253916096 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_be (497) at #4253929128 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4253937556 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process gmain (551) at #4253941529 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sudo (1541) at #4253947300 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4254001908 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_be (497) at #4254005455 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_nss (545) at #4254011736 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4254020384 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sudo (1541) at #4254023383 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_nss (545) at #4254637744 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_be (497) at #4254667420 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sudo (1541) at #4254676314 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_nss (545) at #4257307709 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_be (497) at #4257335349 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_nss (545) at #4257477225 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sudo (1541) at #4257487708 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process kworker/0:2 (88) at #4257594709 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4257602689 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1539) at #4257605586 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4257636964 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process sssd_be (497) at #4257640812 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4257653414 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process ksoftirqd/0 (7) at #4257656527 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process rcu_sched (8) at #4257682937 mov qword ptr gs:[rip+0x7efe7d71], rbx
# Changing to process exploit_userspe (1539) at #4257686785 mov qword ptr gs:[rip+0x7efe7d71], rbx
#  CPU times: user 1.12 s, sys: 173 ms, total: 1.29 s
# Wall time: 15.3 s

# %%
print("Processes:")
for (process_name, process_pid), nb_instrs in reversed(sorted(processes.items(), key=lambda x: x[1])):
    print(" - %s (pid: %d): %d instructions (%.4f%% of the trace)" % (
        process_name, process_pid, 
        nb_instrs, 
        (nb_instrs / last_transition_id) * 100
    ))
# Out:
# Processes:
#  - sudo (pid: 1541): 4041627346 instructions (94.9254% of the trace)
#  - tee (pid: 1543): 83993966 instructions (1.9728% of the trace)
#  - exploit_userspe (pid: 1541): 51378101 instructions (1.2067% of the trace)
#  - sudo (pid: 1543): 37237307 instructions (0.8746% of the trace)
#  - systemd-journal (pid: 373): 18116746 instructions (0.4255% of the trace)
#  - in:imjournal (pid: 493): 3833283 instructions (0.0900% of the trace)
#  - unix_chkpwd (pid: 1542): 3728068 instructions (0.0876% of the trace)
#  - Xorg (pid: 614): 2360334 instructions (0.0554% of the trace)
#  - dbus-daemon (pid: 491): 2134845 instructions (0.0501% of the trace)
#  - sssd_nss (pid: 545): 1681198 instructions (0.0395% of the trace)
#  - rcu_sched (pid: 8): 1640368 instructions (0.0385% of the trace)
#  - xfce4-terminal (pid: 974): 1424720 instructions (0.0335% of the trace)
#  - kworker/0:2 (pid: 88): 875519 instructions (0.0206% of the trace)
#  - kworker/u2:2 (pid: 86): 825146 instructions (0.0194% of the trace)
#  - sudo (pid: 1542): 603026 instructions (0.0142% of the trace)
#  - rs:main Q:Reg (pid: 494): 506026 instructions (0.0119% of the trace)
#  - systemd-logind (pid: 550): 443566 instructions (0.0104% of the trace)
#  - gdbus (pid: 1163): 388230 instructions (0.0091% of the trace)
#  - gdbus (pid: 998): 371386 instructions (0.0087% of the trace)
#  - gdbus (pid: 531): 358666 instructions (0.0084% of the trace)
#  - sedispatch (pid: 468): 348361 instructions (0.0082% of the trace)
#  - xscreensaver (pid: 1065): 311396 instructions (0.0073% of the trace)
#  - python3 (pid: 1269): 297297 instructions (0.0070% of the trace)
#  - auditd (pid: 463): 285472 instructions (0.0067% of the trace)
#  - sssd_be (pid: 497): 264167 instructions (0.0062% of the trace)
#  - gmain (pid: 551): 245205 instructions (0.0058% of the trace)
#  - kworker/0:1 (pid: 1432): 223284 instructions (0.0052% of the trace)
#  - dnfdaemon-syste (pid: 1270): 174486 instructions (0.0041% of the trace)
#  - xfwm4 (pid: 963): 157378 instructions (0.0037% of the trace)
#  - systemd (pid: 1): 156970 instructions (0.0037% of the trace)
#  - avahi-daemon (pid: 501): 142474 instructions (0.0033% of the trace)
#  - ksoftirqd/0 (pid: 7): 134721 instructions (0.0032% of the trace)
#  - audispd (pid: 465): 128707 instructions (0.0030% of the trace)
#  - audispd (pid: 469): 105259 instructions (0.0025% of the trace)
#  - abrt-dump-journ (pid: 543): 99584 instructions (0.0023% of the trace)
#  - jbd2/sda1-8 (pid: 290): 97257 instructions (0.0023% of the trace)
#  - lvmetad (pid: 435): 92774 instructions (0.0022% of the trace)
#  - abrt-dump-journ (pid: 540): 91748 instructions (0.0022% of the trace)
#  - abrt-dump-journ (pid: 541): 82332 instructions (0.0019% of the trace)
#  - xfce4-power-man (pid: 981): 79855 instructions (0.0019% of the trace)
#  - kauditd (pid: 30): 74649 instructions (0.0018% of the trace)
#  - abrt-dbus (pid: 1161): 70396 instructions (0.0017% of the trace)
#  - polkitd (pid: 509): 64427 instructions (0.0015% of the trace)
#  - gmain (pid: 972): 61021 instructions (0.0014% of the trace)
#  - accounts-daemon (pid: 549): 58544 instructions (0.0014% of the trace)
#  - gmain (pid: 520): 48516 instructions (0.0011% of the trace)
#  - gmain (pid: 999): 47921 instructions (0.0011% of the trace)
#  - gpg-agent (pid: 962): 46505 instructions (0.0011% of the trace)
#  - gmain (pid: 1021): 39811 instructions (0.0009% of the trace)
#  - exploit_userspe (pid: 1539): 31378 instructions (0.0007% of the trace)
#  - rsyslogd (pid: 489): 28652 instructions (0.0007% of the trace)
#  - kworker/0:1H (pid: 257): 26589 instructions (0.0006% of the trace)
#  - rtkit-daemon (pid: 521): 15795 instructions (0.0004% of the trace)
#  - rtkit-daemon (pid: 522): 14127 instructions (0.0003% of the trace)
#  - watchdog/0 (pid: 11): 6613 instructions (0.0002% of the trace)
#  - ssh-agent (pid: 933): 5267 instructions (0.0001% of the trace)
